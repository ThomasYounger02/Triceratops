# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 透视
# ## pivot_table
# 比groupby更灵活。
#
# - 可以设定列；
# - margin控制合计列；

# %%
data = {
    'state': ['Ohio', 'Ohio', 'Ohio', 'Nevada', 'Nevada'],
    'year':[2000, 2001, 2002, 2001, 2002],
    'pop': [1.5, 1.7, 3.6, 2.4, 2.9],
    'area': [5.5, 7.7, 6.6, 4.4, 9.9],
    'num':['one', 'two', 'three', 'four', 'five']
}

df = pd.DataFrame(data)

df.head()
# Out:
#     state  year  pop  area    num
# 0    Ohio  2000  1.5   5.5    one
# 1    Ohio  2001  1.7   7.7    two
# 2    Ohio  2002  3.6   6.6  three
# 3  Nevada  2001  2.4   4.4   four
# 4  Nevada  2002  2.9   9.9   five

# %% [markdown]
# ### 设定行

# %%
pd.pivot_table(df, 
               index=['num', 'state'],       # 行标签
               values=['pop', 'area'])       # 聚合数据
# Out:
#               area  pop
# num   state
# five  Nevada   9.9  2.9
# four  Nevada   4.4  2.4
# one   Ohio     5.5  1.5
# three Ohio     6.6  3.6
# two   Ohio     7.7  1.7

# %% [markdown]
# ### 增加聚合方式

# %%
pd.pivot_table(df, 
               index=['num', 'state'],       # 行标签
               values=['pop', 'area'],       # 聚合数据
               aggfunc=[np.sum, np.mean]
              )
# Out:
# /var/folders/0s/f921_t_11c9f501shysndn2w0000gn/T/ipykernel_68243/1735268172.py:1: FutureWarning: The provided callable <function sum at 0x10c590ae0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   pd.pivot_table(df,
# /var/folders/0s/f921_t_11c9f501shysndn2w0000gn/T/ipykernel_68243/1735268172.py:1: FutureWarning: The provided callable <function mean at 0x10c591bc0> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   pd.pivot_table(df,
#               sum      mean
#              area  pop area  pop
# num   state
# five  Nevada  9.9  2.9  9.9  2.9
# four  Nevada  4.4  2.4  4.4  2.4
# one   Ohio    5.5  1.5  5.5  1.5
# three Ohio    6.6  3.6  6.6  3.6
# two   Ohio    7.7  1.7  7.7  1.7

# %% [markdown]
# ### 设定行列

# %%
pd.pivot_table(df, 
               index=['num'],                # 行标签
               columns = ['state'],
               values=['pop', 'area'],       # 聚合数据
               aggfunc=[np.sum],
               fill_value=0
              )
# Out:
# /var/folders/0s/f921_t_11c9f501shysndn2w0000gn/T/ipykernel_68243/581811883.py:1: FutureWarning: The provided callable <function sum at 0x10c590ae0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   pd.pivot_table(df,
#          sum
#         area         pop
# state Nevada Ohio Nevada Ohio
# num
# five     9.9  0.0    2.9  0.0
# four     4.4  0.0    2.4  0.0
# one      0.0  5.5    0.0  1.5
# three    0.0  6.6    0.0  3.6
# two      0.0  7.7    0.0  1.7

# %%
pd.pivot_table(df, 
               index=['num'],                # 行标签
               columns = ['state'],
               values=['pop', 'area'],       # 聚合数据
               aggfunc=[np.sum],
               fill_value=0,
               margins=1                     # 汇总行列
              )
# Out:
# /var/folders/0s/f921_t_11c9f501shysndn2w0000gn/T/ipykernel_68243/1164927090.py:1: FutureWarning: The provided callable <function sum at 0x10c590ae0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   pd.pivot_table(df,
# /var/folders/0s/f921_t_11c9f501shysndn2w0000gn/T/ipykernel_68243/1164927090.py:1: FutureWarning: The provided callable <function sum at 0x10c590ae0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   pd.pivot_table(df,
# /var/folders/0s/f921_t_11c9f501shysndn2w0000gn/T/ipykernel_68243/1164927090.py:1: FutureWarning: The provided callable <function sum at 0x10c590ae0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   pd.pivot_table(df,
#          sum
#         area                pop
# state Nevada  Ohio   All Nevada Ohio   All
# num
# five     9.9   0.0   9.9    2.9  0.0   2.9
# four     4.4   0.0   4.4    2.4  0.0   2.4
# one      0.0   5.5   5.5    0.0  1.5   1.5
# three    0.0   6.6   6.6    0.0  3.6   3.6
# two      0.0   7.7   7.7    0.0  1.7   1.7
# All     14.3  19.8  34.1    5.3  6.8  12.1

# %% [markdown]
# ## groupby

# %%
df.groupby(['num'])[['area', 'pop']].agg(np.sum).fillna(0)
# Out:
# /var/folders/0s/f921_t_11c9f501shysndn2w0000gn/T/ipykernel_68243/3275502569.py:1: FutureWarning: The provided callable <function sum at 0x10c590ae0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   df.groupby(['num'])[['area', 'pop']].agg(np.sum).fillna(0)
#        area  pop
# num
# five    9.9  2.9
# four    4.4  2.4
# one     5.5  1.5
# three   6.6  3.6
# two     7.7  1.7

# %% [markdown]
# # 逆透视
# ## stack
# 将列名转换为普通的列。

# %%
data = {
    'product': list('ABCDE'),
    'Jan': np.random.randn(5),
    'Feb': np.random.randn(5),
    'Mar': np.random.randn(5),
    'Apr': np.random.randn(5),
    'May': np.random.randn(5),
    'Jun': np.random.randn(5)
}

df = pd.DataFrame(data)

df.head()
# Out:
#   product       Jan       Feb       Mar       Apr       May       Jun
# 0       A  0.927846 -0.285866  0.701058 -0.532041  0.734615 -1.243142
# 1       B -1.148570 -1.360192 -0.440771  0.818754 -1.002218 -0.691591
# 2       C -0.066699  0.542037 -0.729462 -0.467078  1.102197  2.384517
# 3       D -0.499626 -1.717789  0.125577  0.469721  0.686662  1.069873
# 4       E -2.234766 -0.660656  1.794696 -0.090528  0.151282  0.753376

# %%
df_stacked = df.set_index('product').stack().reset_index()    # 先将分类变量设为索引，再stack

df_stacked.columns = ['product', 'month', 'sale_amt']
df_stacked.head()
# Out:
#   product month  sale_amt
# 0       A   Jan  0.927846
# 1       A   Feb -0.285866
# 2       A   Mar  0.701058
# 3       A   Apr -0.532041
# 4       A   May  0.734615

# %% [markdown]
# ## 多个分类指标

# %%
data = {
    'product': list('ABCDE'),
    'cat': list('一二一二一'),
    'Jan': np.random.randn(5),
    'Feb': np.random.randn(5),
    'Mar': np.random.randn(5),
    'Apr': np.random.randn(5),
    'May': np.random.randn(5),
    'Jun': np.random.randn(5)
}

df = pd.DataFrame(data)

df.head()
# Out:
#   product cat       Jan       Feb       Mar       Apr       May       Jun
# 0       A   一 -0.125164 -1.262792 -0.822153 -0.433824  0.713923  0.084344
# 1       B   二 -1.595572  1.456221  0.856915  1.536777  1.485050  1.427357
# 2       C   一  3.402358 -0.416169  0.195352 -2.158873 -0.764844  2.043812
# 3       D   二 -0.921769  1.153112 -0.673250  0.228433 -1.405622  0.056650
# 4       E   一  0.847550 -0.345598 -0.801974 -1.082217  0.369749  0.034031

# %%
df_stacked = df.set_index(['cat', 'product']).stack().reset_index()
df_stacked.columns = ['cat', 'product', 'month', 'sale_amt']

df_stacked.head()
# Out:
#   cat product month  sale_amt
# 0   一       A   Jan -0.125164
# 1   一       A   Feb -1.262792
# 2   一       A   Mar -0.822153
# 3   一       A   Apr -0.433824
# 4   一       A   May  0.713923
